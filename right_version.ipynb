# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.09.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.12.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.15.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.18.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.21.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.24.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.27.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\加赛\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.30.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\加赛\Nepomniachtchi, Ian_vs_Ding, Liren_2023.04.30 (1).pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.10.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.13.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.16.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.20.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.23.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.26.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# Exception ignored in: <function Stockfish.__del__ at 0x00000221E4CAA3A0>
# Traceback (most recent call last):
#   File "D:\Anaconda\envs\DL\lib\site-packages\stockfish\models.py", line 757, in __del__
#     if self._stockfish.poll() is None:
# AttributeError: 'Stockfish' object has no attribute '_stockfish'

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    stockfish=Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20) 
  
    with open(r'C:\Users\Administrator\Desktop\2023\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.29.pgn') as pgn_file:
        game=chess.pgn.read_game(pgn_file)

    board=chess.Board() 
    move_scores =[] 

    for move in game.mainline_moves():
        board.push(move) 
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\加赛\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.30.pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()

# %%
import chess
import chess.pgn
from stockfish import Stockfish
import matplotlib.pyplot as plt


def main():
    # 初始化 Stockfish 引擎，确保路径指向你的 Stockfish 可执行文件
    stockfish =Stockfish('C:/Users/Administrator/Desktop/stockfish-windows-x86-64-avx2/stockfish/stockfish-windows-x86-64-avx2.exe')
    stockfish.set_depth(20)  # 设置评估深度

    # 打开 PGN 文件
    with open(r'C:\Users\Administrator\Desktop\2023\加赛\Ding, Liren_vs_Nepomniachtchi, Ian_2023.04.30 (1).pgn') as pgn_file:
        game = chess.pgn.read_game(pgn_file)

    board = chess.Board()  # 初始化棋盘
    move_scores = []  # 存储每一步的分数

    # 遍历游戏的主线路走法
    for move in game.mainline_moves():
        board.push(move)  # 走棋
        # 将当前棋盘状态传递给 Stockfish
        stockfish.set_fen_position(board.fen())
        # 获取评估结果
        evaluation = stockfish.get_evaluation()
        if evaluation["type"] == "cp":  # 中心点数评估
            score = evaluation["value"]
        elif evaluation["type"] == "mate":  # 将军评估
            score = evaluation["value"]
        move_scores.append(score)  # 存储分数

    # 绘制分数图
    move_numbers = list(range(1, len(move_scores) + 1))
    plt.plot(move_numbers, move_scores)
    plt.xlabel('Move Number')
    plt.ylabel('Stockfish Score')
    plt.title('Score Evaluation of Each Move')
    plt.show()


if __name__ == "__main__":
    main()
